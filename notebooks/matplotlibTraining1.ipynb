# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#np.random.random gera um número de 0 a 1 e depois multiplicamos por 100

x_data = np.random.random(1000) * 100
y_data = np.random.random(1000) * 100
plt.scatter(x_data, y_data, c="red", marker="*", s=150, alpha=0.3)

# %%
years= [2005 + x for x in range(16)]
weights = [80, 82, 84, 85, 83, 80, 79, 83, 85, 82, 90, 92, 90, 87, 85, 82]

plt.plot(years, weights, c="red", lw=3, linestyle="--")
# c= "r--" também funciona

# %%
x = ["C++", "C#", "Python", "Java", "Go"]
y= [20, 50, 140, 1, 45]

plt.bar(x, y, color="r", align="edge", width=0.2, edgecolor="black", lw=6)
# Out:
# <BarContainer object of 5 artists>

# %%
ages= np.random.normal(20, 1.5, 1000)
plt.hist(ages, bins=20, cumulative=True)
# Out:
# (array([   3.,    8.,   15.,   37.,   67.,  117.,  197.,  298.,  420.,
#          521.,  641.,  754.,  839.,  909.,  956.,  971.,  988.,  992.,
#          996., 1000.]),
#  array([15.44584921, 15.91206398, 16.37827875, 16.84449351, 17.31070828,
#         17.77692305, 18.24313782, 18.70935259, 19.17556736, 19.64178213,
#         20.10799689, 20.57421166, 21.04042643, 21.5066412 , 21.97285597,
#         22.43907074, 22.90528551, 23.37150027, 23.83771504, 24.30392981,
#         24.77014458]),
#  <BarContainer object of 20 artists>)

# %%
langs = ["C++", "C#", "Python", "Java", "Go"]
votes= [20, 24, 14, 6, 17]
explodes = [0, 0,0 ,0.2,0]

plt.pie(votes, labels=langs, explode=explodes, autopct="%.2f%%", pctdistance=1.3, startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fed5863b10>,
# ...
#  [Text(-0.7853227396757139, -0.7702390502618206, 'C++'),
#   Text(0.8694317503583906, -0.6738608398391654, 'C#'),
#   Text(0.7548656648207942, 0.8001111348273191, 'Python'),
#   Text(-0.025208476644425264, 1.2997555665221319, 'Java'),
#   Text(-0.8694313272861753, 0.6738613856969397, 'Go')],
#  [Text(-0.9281086923440254, -0.9102825139457879, '24.69%'),
#   Text(1.0275102504235525, -0.7963809925371955, '29.63%'),
#   Text(0.892113967515484, 0.9455858866141044, '17.28%'),
#   Text(-0.029086703820490688, 1.4997179613716904, '7.41%'),
#   Text(-1.0275097504291162, 0.7963816376418377, '20.99%')])

# %%
heights = np.random.normal(172, 8, 300)

# %%
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fed58b5c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fed58b7350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fed58b5250>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fed58c48d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fed58c5350>],
#  'means': []}

# %%
year= [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
income=[55,56,62,61,72,72,73,75]
income_ticks = list(range(50,81,2))

# %%
plt.plot(year, income)
plt.title("Income of John", fontsize=30, fontname="Times New Roman")
plt.xlabel("Year")
plt.ylabel("Yearly Income €")
plt.yticks(income_ticks, [f"{x}k €" for x in income_ticks])
# Out:
# ([<matplotlib.axis.YTick at 0x25d30b77850>,
# ...
#  [Text(0, 50, '50k €'),
#   Text(0, 52, '52k €'),
#   Text(0, 54, '54k €'),
#   Text(0, 56, '56k €'),
#   Text(0, 58, '58k €'),
#   Text(0, 60, '60k €'),
#   Text(0, 62, '62k €'),
#   Text(0, 64, '64k €'),
#   Text(0, 66, '66k €'),
#   Text(0, 68, '68k €'),
#   Text(0, 70, '70k €'),
#   Text(0, 72, '72k €'),
#   Text(0, 74, '74k €'),
#   Text(0, 76, '76k €'),
#   Text(0, 78, '78k €'),
#   Text(0, 80, '80k €')])

# %%
stock_a = [100, 102, 99, 101, 101, 100, 102]
stock_b = [90, 95, 102, 104, 105, 103, 109]
stock_c = [110, 115, 100, 105, 100, 98, 95]

plt.plot(stock_a, label="Company1")
plt.plot(stock_b, label="Company2")
plt.plot(stock_c, label="Company3")

plt.legend(loc="lower right")

# %%
vote = [10,2,5,16,22]
people=["A","B","C","D","E"]

plt.pie(vote, labels=None)
plt.legend(labels= people)

# %%
from matplotlib import style

style.use("dark_background")

vote = [10,2,5,16,22]
people=["A","B","C","D","E"]

plt.pie(vote, labels=None)
plt.legend(labels= people)

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.random.random(100), np.random.random(100)

plt.figure(1)
plt.scatter(x1,y1)

plt.figure(2)
plt.plot(x2, y2)

# %%
x = np.arange(100)

fig, axs= plt.subplots(2,2)
axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title("Sine Wave")

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title("Cosine Wave")

axs[1,0].plot(x, np.random.random(100))
axs[1,0].set_title("Random Function")

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title("Random Function")
axs[1,1].set_xlabel("Test")

fig.suptitle("Four Plots", fontsize="30")
plt.tight_layout()
plt.savefig("fourplots.png", dpi=300, )
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18540\37806415.py:13: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))

# %%
plt.savefig("fourplots.png", dpi=300, bbox_inches="tight")

# %%
ax= plt.axes(projection="3d")
x=np.arange(0, 50, 0.1)
y=np.sin(x)
z=np.cos(x)

ax.plot(x, y, z)
ax.set_title("3D Plot")
ax.set_xlabel("test")
# Out:
# Text(0.5, 0, 'test')

# %%
ax= plt.axes(projection="3d")
x=np.arange(-5, 5, 0.1)
y=np.arange(-5,5,0.1)

X, Y= np.meshgrid(x,y)

Z= np.sin(X) * np.cos(Y)

ax.plot_surface(X,Y,Z, cmap="Spectral")
ax.set_title("3D Plot")
ax.set_xlabel("test")
ax.view_init(azim=0, elev=90)

# %%
import random
